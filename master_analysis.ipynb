# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

financial_file = Path("Resources/salaries_per_city.csv")
FBI10_path = 'Resources\FBI_2010_illinois_amended.csv'
FBI11_path = 'Resources\FBI_2011_illinois_amended.csv'
FBI12_path = 'Resources\FBI_2012_illinois_amended.csv'
FBI13_path = 'Resources\FBI_2013_illinois_amended.csv'
FBI14_path = 'Resources\FBI_2014_illinois_amended.csv'
FBI15_path = 'Resources\FBI_2015_illinois_amended.csv'
FBI16_path = 'Resources\FBI_2016_illinois_amended.csv'
FBI17_path = 'Resources\FBI_2017_illinois_amended.csv'
FBI18_path = 'Resources\FBI_2018_illinois_amended.csv'
FBI19_path = 'Resources\FBI_2019_illinois_amended.csv'

# %%
crime10_base = pd.read_csv(FBI10_path, delimiter=',')
crime11_base = pd.read_csv(FBI11_path, delimiter=',')
crime12_base = pd.read_csv(FBI12_path, delimiter=',')
crime13_base = pd.read_csv(FBI13_path, delimiter=',')
crime14_base = pd.read_csv(FBI14_path, delimiter=',')
crime15_base = pd.read_csv(FBI15_path, delimiter=',')
crime16_base = pd.read_csv(FBI16_path, delimiter=',')
crime17_base = pd.read_csv(FBI17_path, delimiter=',')
crime18_base = pd.read_csv(FBI18_path, delimiter=',')
crime19_base = pd.read_csv(FBI19_path, delimiter=',')

crime10_stats = crime10_base.fillna(0)
crime11_stats = crime11_base.fillna(0)
crime12_stats = crime12_base.fillna(0)
crime13_stats = crime13_base.fillna(0)
crime14_stats = crime14_base.fillna(0)
crime15_stats = crime15_base.fillna(0)
crime16_stats = crime16_base.fillna(0)
crime17_stats = crime17_base.fillna(0)
crime18_stats = crime18_base.fillna(0)
crime19_stats = crime19_base.fillna(0)

crime10_stats['Year'] = 2010
crime11_stats['Year'] = 2011
crime12_stats['Year'] = 2012
crime13_stats['Year'] = 2013
crime14_stats['Year'] = 2014
crime15_stats['Year'] = 2015
crime16_stats['Year'] = 2016
crime17_stats['Year'] = 2017
crime18_stats['Year'] = 2018
crime19_stats['Year'] = 2019

crime10_complete = crime10_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime11_complete = crime11_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime12_complete = crime12_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime13_complete = crime13_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime14_complete = crime14_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime15_complete = crime15_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime16_complete = crime16_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime17_complete = crime17_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime18_complete = crime18_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]
crime19_complete = crime19_stats[['City', 'Year', 'Population', 'Violent crime',
       'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',
       'Aggravated Assault', 'Property Crime', 'Burglary', 'Larceny-theft',
       'Motor vehicle theft', 'Arson']]

crime_stats_df = pd.concat([crime10_complete, 
                            crime11_complete, 
                            crime12_complete, 
                            crime13_complete, 
                            crime14_complete, 
                            crime15_complete, 
                            crime16_complete, 
                            crime17_complete, 
                            crime18_complete, 
                            crime19_complete], ignore_index=True, axis=0)
#crime_stats_df

crime_stats_df['Population'] = crime_stats_df['Population'].str.replace(',','')
crime_stats_df['Violent crime'] = crime_stats_df['Violent crime'].str.replace(',','')
crime_stats_df['Rape'] = crime_stats_df['Rape'].str.replace(',','')
crime_stats_df['Robbery'] = crime_stats_df['Robbery'].str.replace(',','')
crime_stats_df['Aggravated Assault'] = crime_stats_df['Aggravated Assault'].str.replace(',','')
crime_stats_df['Property Crime'] = crime_stats_df['Property Crime'].str.replace(',','')
crime_stats_df['Burglary'] = crime_stats_df['Burglary'].str.replace(',','')
crime_stats_df['Larceny-theft'] = crime_stats_df['Larceny-theft'].str.replace(',','')
crime_stats_df['Motor vehicle theft'] = crime_stats_df['Motor vehicle theft'].str.replace(',','')


crime_stats_df['Population'] = crime_stats_df['Population'].astype('float64')
crime_stats_df['Violent crime'] = crime_stats_df['Violent crime'].astype('float64')
crime_stats_df['Rape'] = crime_stats_df['Rape'].astype('float64')
crime_stats_df['Robbery'] = crime_stats_df['Robbery'].astype('float64')
crime_stats_df['Aggravated Assault'] = crime_stats_df['Aggravated Assault'].astype('float64')
crime_stats_df['Property Crime'] = crime_stats_df['Property Crime'].astype('float64')
crime_stats_df['Burglary'] = crime_stats_df['Burglary'].astype('float64')
crime_stats_df['Larceny-theft'] = crime_stats_df['Larceny-theft'].astype('float64')
crime_stats_df['Motor vehicle theft'] = crime_stats_df['Motor vehicle theft'].astype('float64')

crime_stats_df = crime_stats_df.fillna(0)
crime_stats_df
# Out:
#             City  Year  Population  Violent crime  \
# 0        Addison  2010     36581.0           67.0
# 1         Albany  2010       917.0            0.0
# 2          Aledo  2010      3466.0           11.0
# 3      Algonquin  2010     30848.0           79.0
# 4          Alton  2010     28841.0          174.0
# ...          ...   ...         ...            ...
# 4936   Woodstock  2019     25324.0           18.0
# 4937       Worth  2019     10534.0           31.0
# 4938  Yates City  2019       653.0            0.0
# 4939   Yorkville  2019     20541.0           28.0
# 4940        Zion  2019     23617.0          130.0
#
#       Murder and Non-Negligent Manslaughter  Rape  Robbery  \
# 0                                       0.0   0.0     17.0
# 1                                       0.0   0.0      0.0
# 2                                       0.0   0.0      0.0
# 3                                       0.0   0.0      2.0
# 4                                       4.0   0.0     27.0
# ...

# %%
chicago_df = crime_stats_df.loc[crime_stats_df['City'] == 'Chicago'].copy()
chicago_df['Violent crime per Population'] = ((chicago_df['Violent crime'] / chicago_df['Population']) * 100)
chicago_df['Murder and Non-Negligent Manslaughter per Population'] = ((chicago_df['Murder and Non-Negligent Manslaughter'] / chicago_df['Population']) * 100)
chicago_df['Rape per Population'] = ((chicago_df['Rape'] / chicago_df['Population']) * 100)
chicago_df['Robbery per Population'] = ((chicago_df['Robbery'] / chicago_df['Population']) * 100)
chicago_df['Aggravated Assault per Population'] = ((chicago_df['Aggravated Assault'] / chicago_df['Population']) * 100)
chicago_df['Property crime per Population'] = ((chicago_df['Property Crime'] / chicago_df['Population']) * 100)
chicago_df['Burglary per Population'] = ((chicago_df['Burglary'] / chicago_df['Population']) * 100)
chicago_df['Larceny-theft per Population'] = ((chicago_df['Larceny-theft'] / chicago_df['Population']) * 100)
chicago_df['Motor vehicle theft per Population'] = ((chicago_df['Motor vehicle theft'] / chicago_df['Population']) * 100)
chicago_df['Arson per Population'] = ((chicago_df['Arson'] / chicago_df['Population']) * 100)
chicago_df
# Out:
#          City  Year  Population  Violent crime  \
# 68    Chicago  2010   2833649.0            0.0
# 484   Chicago  2011   2703713.0            0.0
# 863   Chicago  2012   2708382.0            0.0
# 1378  Chicago  2013   2720554.0            0.0
# 1881  Chicago  2014   2724121.0        24089.0
# 2373  Chicago  2015   2728695.0        24663.0
# 2889  Chicago  2016   2725153.0        30126.0
# 3424  Chicago  2017   2706171.0        29737.0
# 3968  Chicago  2018   2719151.0        27357.0
# 4490  Chicago  2019   2707064.0        25532.0
#
#       Murder and Non-Negligent Manslaughter    Rape  Robbery  \
# 68                                    432.0     0.0  14213.0
# 484                                   431.0     0.0  13975.0
# 863                                   500.0     0.0  13476.0
# 1378                                  414.0     0.0  11815.0
# 1881                                  411.0  1343.0   9804.0
# 2373                                  478.0  1432.0   9649.0
# ...

# %%
naperville_df = crime_stats_df.loc[crime_stats_df['City'] == 'Naperville'].copy()
naperville_df['Violent crime per Population'] = ((naperville_df['Violent crime'] / naperville_df['Population']) * 100)
naperville_df['Murder and Non-Negligent Manslaughter per Population'] = ((naperville_df['Murder and Non-Negligent Manslaughter'] / naperville_df['Population']) * 100)
naperville_df['Rape per Population'] = ((naperville_df['Rape'] / naperville_df['Population']) * 100)
naperville_df['Robbery per Population'] = ((naperville_df['Robbery'] / naperville_df['Population']) * 100)
naperville_df['Aggravated Assault per Population'] = ((naperville_df['Aggravated Assault'] / naperville_df['Population']) * 100)
naperville_df['Property crime per Population'] = ((naperville_df['Property Crime'] / naperville_df['Population']) * 100)
naperville_df['Burglary per Population'] = ((naperville_df['Burglary'] / naperville_df['Population']) * 100)
naperville_df['Larceny-theft per Population'] = ((naperville_df['Larceny-theft'] / naperville_df['Population']) * 100)
naperville_df['Motor vehicle theft per Population'] = ((naperville_df['Motor vehicle theft'] / naperville_df['Population']) * 100)
naperville_df['Arson per Population'] = ((naperville_df['Arson'] / naperville_df['Population']) * 100)
naperville_df
# Out:
#             City  Year  Population  Violent crime  \
# 643   Naperville  2011    142280.0          112.0
# 1106  Naperville  2012    142840.0          119.0
# 1616  Naperville  2013    144221.0          105.0
# 2108  Naperville  2014    145510.0          113.0
# 2620  Naperville  2015    147101.0          128.0
# 3139  Naperville  2016    148070.0           92.0
# 3676  Naperville  2017    147934.0          136.0
# 4208  Naperville  2018    148457.0          102.0
#
#       Murder and Non-Negligent Manslaughter  Rape  Robbery  \
# 643                                     2.0   0.0     24.0
# 1106                                    3.0   0.0     24.0
# 1616                                    0.0   0.0     21.0
# 2108                                    1.0   8.0     20.0
# 2620                                    0.0  14.0     27.0
# 3139                                    0.0  15.0     34.0
# 3676                                    1.0  22.0     33.0
# ...

# %%
springfield_df = crime_stats_df.loc[crime_stats_df['City'] == 'Springfield'].copy()
springfield_df['Violent crime per Population'] = ((springfield_df['Violent crime'] / springfield_df['Population']) * 100)
springfield_df['Murder and Non-Negligent Manslaughter per Population'] = ((springfield_df['Murder and Non-Negligent Manslaughter'] / springfield_df['Population']) * 100)
springfield_df['Rape per Population'] = ((springfield_df['Rape'] / springfield_df['Population']) * 100)
springfield_df['Robbery per Population'] = ((springfield_df['Robbery'] / springfield_df['Population']) * 100)
springfield_df['Aggravated Assault per Population'] = ((springfield_df['Aggravated Assault'] / springfield_df['Population']) * 100)
springfield_df['Property crime per Population'] = ((springfield_df['Property Crime'] / springfield_df['Population']) * 100)
springfield_df['Burglary per Population'] = ((springfield_df['Burglary'] / springfield_df['Population']) * 100)
springfield_df['Larceny-theft per Population'] = ((springfield_df['Larceny-theft'] / springfield_df['Population']) * 100)
springfield_df['Motor vehicle theft per Population'] = ((springfield_df['Motor vehicle theft'] / springfield_df['Population']) * 100)
springfield_df['Arson per Population'] = ((springfield_df['Arson'] / springfield_df['Population']) * 100)
springfield_df
# Out:
#              City  Year  Population  Violent crime  \
# 368   Springfield  2010    117383.0         1452.0
# 734   Springfield  2011    116600.0         1278.0
# 1223  Springfield  2012    117131.0         1138.0
# 1738  Springfield  2013    117351.0         1191.0
# 2224  Springfield  2014    117134.0         1248.0
# 2736  Springfield  2015    116875.0         1251.0
# 3265  Springfield  2016    116563.0         1301.0
# 3807  Springfield  2017    115568.0         1219.0
# 4334  Springfield  2018    114623.0          955.0
# 4872  Springfield  2019    114393.0          889.0
#
#       Murder and Non-Negligent Manslaughter   Rape  Robbery  \
# 368                                     7.0    0.0    338.0
# 734                                     8.0    0.0    258.0
# 1223                                   10.0    0.0    260.0
# 1738                                    4.0    0.0    287.0
# 2224                                    4.0   97.0    258.0
# ...

# %%
park_ridge_df = crime_stats_df.loc[crime_stats_df['City'] == 'Park Ridge'].copy()
park_ridge_df['Violent crime per Population'] = ((park_ridge_df['Violent crime'] / park_ridge_df['Population']) * 100)
park_ridge_df['Murder and Non-Negligent Manslaughter per Population'] = ((park_ridge_df['Murder and Non-Negligent Manslaughter'] / park_ridge_df['Population']) * 100)
park_ridge_df['Rape per Population'] = ((park_ridge_df['Rape'] / park_ridge_df['Population']) * 100)
park_ridge_df['Robbery per Population'] = ((park_ridge_df['Robbery'] / park_ridge_df['Population']) * 100)
park_ridge_df['Aggravated Assault per Population'] = ((park_ridge_df['Aggravated Assault'] / park_ridge_df['Population']) * 100)
park_ridge_df['Property crime per Population'] = ((park_ridge_df['Property Crime'] / park_ridge_df['Population']) * 100)
park_ridge_df['Burglary per Population'] = ((park_ridge_df['Burglary'] / park_ridge_df['Population']) * 100)
park_ridge_df['Larceny-theft per Population'] = ((park_ridge_df['Larceny-theft'] / park_ridge_df['Population']) * 100)
park_ridge_df['Motor vehicle theft per Population'] = ((park_ridge_df['Motor vehicle theft'] / park_ridge_df['Population']) * 100)
park_ridge_df['Arson per Population'] = ((park_ridge_df['Arson'] / park_ridge_df['Population']) * 100)
park_ridge_df
# Out:
#             City  Year  Population  Violent crime  \
# 303   Park Ridge  2010     36324.0           15.0
# 677   Park Ridge  2011     37593.0           23.0
# 1147  Park Ridge  2012     37660.0           22.0
# 1660  Park Ridge  2013     37788.0           15.0
# 2148  Park Ridge  2014     37919.0           12.0
# 3183  Park Ridge  2016     37805.0           12.0
# 3720  Park Ridge  2017     37492.0           15.0
# 4251  Park Ridge  2018     37490.0           21.0
# 4785  Park Ridge  2019     37206.0           11.0
#
#       Murder and Non-Negligent Manslaughter  Rape  Robbery  \
# 303                                     0.0   0.0      4.0
# 677                                     0.0   0.0      7.0
# 1147                                    1.0   0.0     12.0
# 1660                                    0.0   0.0      6.0
# 2148                                    0.0   1.0      4.0
# 3183                                    0.0   1.0      8.0
# ...

# %%
bolingbrook_df = crime_stats_df.loc[crime_stats_df['City'] == 'Bolingbrook'].copy()
bolingbrook_df['Violent crime per Population'] = ((bolingbrook_df['Violent crime'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Murder and Non-Negligent Manslaughter per Population'] = ((bolingbrook_df['Murder and Non-Negligent Manslaughter'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Rape per Population'] = ((bolingbrook_df['Rape'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Robbery per Population'] = ((bolingbrook_df['Robbery'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Aggravated Assault per Population'] = ((bolingbrook_df['Aggravated Assault'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Property crime per Population'] = ((bolingbrook_df['Property Crime'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Burglary per Population'] = ((bolingbrook_df['Burglary'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Larceny-theft per Population'] = ((bolingbrook_df['Larceny-theft'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Motor vehicle theft per Population'] = ((bolingbrook_df['Motor vehicle theft'] / bolingbrook_df['Population']) * 100)
bolingbrook_df['Arson per Population'] = ((bolingbrook_df['Arson'] / bolingbrook_df['Population']) * 100)
bolingbrook_df
# Out:
#              City  Year  Population  Violent crime  \
# 455   Bolingbrook  2011     73587.0          161.0
# 826   Bolingbrook  2012     73836.0          180.0
# 1342  Bolingbrook  2013     74224.0          174.0
# 1844  Bolingbrook  2014     74049.0          156.0
# 2333  Bolingbrook  2015     74356.0          136.0
# 2847  Bolingbrook  2016     74471.0          158.0
# 3385  Bolingbrook  2017     74692.0          140.0
# 3928  Bolingbrook  2018     75451.0          112.0
# 4450  Bolingbrook  2019     75394.0          123.0
#
#       Murder and Non-Negligent Manslaughter  Rape  Robbery  \
# 455                                     1.0   0.0     49.0
# 826                                     1.0   0.0     50.0
# 1342                                    1.0   0.0     38.0
# 1844                                    0.0  17.0     46.0
# 2333                                    2.0  24.0     22.0
# 2847                                    2.0  23.0     18.0
# ...

# %%
# make variables for x and y for Violent Crime and use them to create line plot 
# to illustrate the trend over the year provided 
chi_x = chicago_df['Year']
chi_vcrime_y = chicago_df['Violent crime per Population']
naperville_x = naperville_df['Year']
naperville_vcrime_y = naperville_df['Violent crime per Population']
springfield_x = springfield_df['Year']
springfield_vcrime_y = springfield_df['Violent crime per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_vcrime_y = park_ridge_df['Violent crime per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_vcrime_y = bolingbrook_df['Violent crime per Population']
plt.plot(chi_x, chi_vcrime_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_vcrime_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_vcrime_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_vcrime_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_vcrime_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Violent Crime as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/violent_crimes.png')

# %%
# make variables for x and y for Murder and Non-Negligent Manslaughter per Population and 
# use them to create line plot to illustrate the trend over the year provided 
chi_x = chicago_df['Year']
chi_murder_y = chicago_df['Murder and Non-Negligent Manslaughter per Population']
naperville_x = naperville_df['Year']
naperville_murder_y = naperville_df['Murder and Non-Negligent Manslaughter per Population']
springfield_x = springfield_df['Year']
springfield_murder_y = springfield_df['Murder and Non-Negligent Manslaughter per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_murder_y = park_ridge_df['Murder and Non-Negligent Manslaughter per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_murder_y = bolingbrook_df['Murder and Non-Negligent Manslaughter per Population']
plt.plot(chi_x, chi_murder_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_murder_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_murder_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_murder_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_murder_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Murder and Non-Negligent Manslaughter as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/Murder_Manslaughter.png')

# %%
# make variables for x and y for Rape and use them to create line plot 
# to illustrate the trend over the year provided 
chi_x = chicago_df['Year']
chi_rape_y = chicago_df['Rape per Population']
naperville_x = naperville_df['Year']
naperville_rape_y = naperville_df['Rape per Population']
springfield_x = springfield_df['Year']
springfield_rape_y = springfield_df['Rape per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_rape_y = park_ridge_df['Rape per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_rape_y = bolingbrook_df['Rape per Population']
plt.plot(chi_x, chi_rape_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_rape_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_rape_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_rape_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_rape_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Rape as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/rape.png')

# %%
# make variables for x and y for Robbery and use them to create line plot 
# to illustrate the trend over the year provided 
chi_x = chicago_df['Year']
chi_robbery_y = chicago_df['Robbery per Population']
naperville_x = naperville_df['Year']
naperville_robbery_y = naperville_df['Robbery per Population']
springfield_x = springfield_df['Year']
springfield_robbery_y = springfield_df['Robbery per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_robbery_y = park_ridge_df['Robbery per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_robbery_y = bolingbrook_df['Robbery per Population']
plt.plot(chi_x, chi_robbery_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_robbery_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_robbery_y, label='Springfield',marker='s')
plt.plot(park_ridge_x, park_ridge_robbery_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_robbery_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Robbery as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/robbery.png')

# %%
# make variables for x and y for Aggravated Assault and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_assault_y = chicago_df['Aggravated Assault per Population']
naperville_x = naperville_df['Year']
naperville_assault_y = naperville_df['Aggravated Assault per Population']
springfield_x = springfield_df['Year']
springfield_assault_y = springfield_df['Aggravated Assault per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_assault_y = park_ridge_df['Aggravated Assault per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_assault_y = bolingbrook_df['Aggravated Assault per Population']
plt.plot(chi_x, chi_assault_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_assault_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_assault_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_assault_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_assault_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Aggravated Assault as a Percentage of City Population')
plt.legend()
plt.savefig("output_data/aggravated_assault.png")

# %%
# make variables for x and y for Property Crime and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_property_y = chicago_df['Property crime per Population']
naperville_x = naperville_df['Year']
naperville_property_y = naperville_df['Property crime per Population']
springfield_x = springfield_df['Year']
springfield_property_y = springfield_df['Property crime per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_property_y = park_ridge_df['Property crime per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_property_y = bolingbrook_df['Property crime per Population']
plt.plot(chi_x, chi_property_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_property_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_property_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_property_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_property_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Property Crime as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/property_crime.png')

# %%
# make variables for x and y for Burglary and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_burglary_y = chicago_df['Burglary per Population']
naperville_x = naperville_df['Year']
naperville_burglary_y = naperville_df['Burglary per Population']
springfield_x = springfield_df['Year']
springfield_burglary_y = springfield_df['Burglary per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_burglary_y = park_ridge_df['Burglary per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_burglary_y = bolingbrook_df['Burglary per Population']
plt.plot(chi_x, chi_burglary_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_burglary_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_burglary_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_burglary_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_burglary_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Burglary as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/burglary.png')

# %%
# make variables for x and y for Larceny-theft and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_larceny_y = chicago_df['Larceny-theft per Population']
naperville_x = naperville_df['Year']
naperville_larceny_y = naperville_df['Larceny-theft per Population']
springfield_x = springfield_df['Year']
springfield_larceny_y = springfield_df['Larceny-theft per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_larceny_y = park_ridge_df['Larceny-theft per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_larceny_y = bolingbrook_df['Larceny-theft per Population']
plt.plot(chi_x, chi_larceny_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_larceny_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_larceny_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_larceny_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_larceny_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Larceny-theft as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/Larceny_Theft.png')

# %%
# make variables for x and y for Motor vehicle theft and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_vehicle_y = chicago_df['Motor vehicle theft per Population']
naperville_x = naperville_df['Year']
naperville_vehicle_y = naperville_df['Motor vehicle theft per Population']
springfield_x = springfield_df['Year']
springfield_vehicle_y = springfield_df['Motor vehicle theft per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_vehicle_y = park_ridge_df['Motor vehicle theft per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_vehicle_y = bolingbrook_df['Motor vehicle theft per Population']
plt.plot(chi_x, chi_vehicle_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_vehicle_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_vehicle_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_vehicle_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_vehicle_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Motor Vehicle Theft as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/Vehicle_Theft.png')

# %%
# make variables for x and y for Arson and use them to create line plot 
# to illustrate the trend over the year provided
chi_x = chicago_df['Year']
chi_arson_y = chicago_df['Arson per Population']
naperville_x = naperville_df['Year']
naperville_arson_y = naperville_df['Arson per Population']
springfield_x = springfield_df['Year']
springfield_arson_y = springfield_df['Arson per Population']
park_ridge_x = park_ridge_df['Year']
park_ridge_arson_y = park_ridge_df['Arson per Population']
bolingbrook_x = bolingbrook_df['Year']
bolingbrook_arson_y = bolingbrook_df['Arson per Population']
plt.plot(chi_x, chi_arson_y,label='Chicago', marker='*')
plt.plot(naperville_x, naperville_arson_y, label='Naperville', marker='o')
plt.plot(springfield_x, springfield_arson_y, label='Springfield', marker='s')
plt.plot(park_ridge_x, park_ridge_arson_y, label='Park Ridge', marker='^')
plt.plot(bolingbrook_x, bolingbrook_arson_y, label='Bolingbrook', marker='d')
plt.xlabel('Year')
plt.ylabel('% of Total Population')
plt.title('Arson as a Percentage of City Population')
plt.legend()
plt.savefig('output_data/Arson.png')

# %%
chi_pop = chicago_df.groupby('Year')['Property Crime'].sum()
chi_pop
naperville_df = crime_stats_df.loc[crime_stats_df['City'] == 'Naperville']
naperville_pop = naperville_df.groupby('Year')['Property Crime'].sum()
naperville_pop
springfield_df = crime_stats_df.loc[crime_stats_df['City'] == 'Springfield']
springfield_pop = springfield_df.groupby('Year')['Property Crime'].sum()
springfield_pop
park_ridge_df = crime_stats_df.loc[crime_stats_df['City'] == 'Park Ridge']
park_ridge_pop = park_ridge_df.groupby('Year')['Property Crime'].sum()
park_ridge_pop
bolingbrook_df = crime_stats_df.loc[crime_stats_df['City'] == 'Bolingbrook']
bolingbrook_pop = bolingbrook_df.groupby('Year')['Property Crime'].sum()
bolingbrook_pop
# Out:
# Year
# 2011    1221.0
# 2012    1139.0
# 2013    1131.0
# 2014     986.0
# 2015     991.0
# 2016     944.0
# 2017     735.0
# 2018     592.0
# 2019     650.0
# Name: Property Crime, dtype: float64

# %%
cities_to_compare = ["Chicago", "Naperville", "Springfield", "Bolingbrook", "Park Ridge"]

filtered_data = crime_stats_df[(crime_stats_df['Year'] == 2018) & (crime_stats_df['City'].isin(cities_to_compare))]

plt.figure(figsize=(8, 3))
plt.bar(filtered_data['City'], filtered_data['Property Crime'], color='skyblue')
plt.xlabel("Cities")
plt.ylabel("Property Crime Rate")
plt.title(f"Property Crime Rates in 2018 (Selected Cities)")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.savefig('output_data/2018_crime_rates.png')

# %%
specific_cities = ["Chicago", "Naperville", "Springfield", "Bolingbrook", "Park Ridge"]

# Filter data for the specific cities
filtered_data = crime_stats_df[crime_stats_df['City'].isin(specific_cities)]

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year', y='Property Crime', hue='City', data=filtered_data, s=100, palette='Set1')

# Set labels and title
plt.xlabel("Year")
plt.ylabel("Property Crime Total")
plt.title("Property Crime Totals for Specific Cities")

# Save the graph
plt.savefig('output_data/multi_year_property.png')

# Display the plot
plt.show()

# %%
chicago_df.groupby('City').sum()
# Out:
#           Year  Population  Violent crime  \
# City
# Chicago  20145  27276653.0       161504.0
#
#          Murder and Non-Negligent Manslaughter    Rape   Robbery  \
# City
# Chicago                                 5139.0  9685.0  114443.0
#
#          Aggravated Assault  Property Crime  Burglary  Larceny-theft  ...  \
# City                                                                  ...
# Chicago            125930.0        954753.0  169268.0       654815.0  ...
#
#          Violent crime per Population  \
# City
# Chicago                       5.94171
#
#          Murder and Non-Negligent Manslaughter per Population  \
# City
# Chicago                                           0.188552
#
#          Rape per Population  Robbery per Population  \
# City
# Chicago             0.356374                4.192878
#
#          Aggravated Assault per Population  Property crime per Population  \
# City
# Chicago                           4.616609                      34.978981
#
# ...

# %%
crime_total = crime_stats_df.drop(['Population', 'Year'],axis = 1)
crime_total.sum(numeric_only=True).sort_values().plot.barh()
plt.xlabel('Crime Rate')
plt.ylabel('Type of Crime')
plt.title('Most Popuar crimes in Illinois')
plt.savefig('output_data/Most_popular_crimes_IL.png')

# %%
#GENDER & AGE ANALYSIS
FIRST_YEAR = 2010  
LAST_YEAR = 2022

# %%
list(range(FIRST_YEAR,LAST_YEAR+1))
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
age_df = pd.DataFrame(columns=['Age'])
for year in list(range(FIRST_YEAR, LAST_YEAR+1)):
    print(year)
    age_path = f'Resources/Offender Age_{year}.csv'
    df = pd.read_csv(age_path).rename(columns={'# of Crimes': year})
    age_df = age_df.merge(df, how='right', on='Age')
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
age_df
# Out:
#             Age  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# 0      20 to 29  1190  1043  1061   975   932  1200  1138   958   852   744
# 1       Unknown   480   521   494   541   524   673   727   619   516   449
# 2      10 to 19   967   867   684   507   519   660   604   525   426   392
# 3      30 to 39   363   382   386   333   320   347   403   395   474   370
# 4      40 to 49   183   164   207   178   153   156   179   146   214   143
# 5      50 to 59    69    96    85    72    90    80    99    93   114    93
# 6      60 to 69     9    18    20    13     9    17    24    18    19    22
# 7      70 to 79     1     2     6     4     1     4     1     5     6     5
# 8   90 to Older    17     2     0     5     2     0     0     0     0     0
# 9        0 to 9    13     6     6     6     6     9     9     9     5     1
# 10     80 to 89     0     1     2     2     0     1     0     2     0     1
#
#     2020  2021   2022
# 0    746  7055  10499
# ...

# %%
Offender_by_Sex_path = 'Resources/Offender Sex_by year.csv'
Offender_by_Age2010_path = 'Resources/Offender Age_2010.csv'
Offender_by_Age2011_path = 'Resources/Offender Age_2011.csv'
Offender_by_Age2012_path = 'Resources/Offender Age_2012.csv'
Offender_by_Age2013_path = 'Resources/Offender Age_2013.csv'
Offender_by_Age2014_path = 'Resources/Offender Age_2014.csv'
Offender_by_Age2015_path = 'Resources/Offender Age_2015.csv'
Offender_by_Age2016_path = 'Resources/Offender Age_2016.csv'
Offender_by_Age2017_path = 'Resources/Offender Age_2017.csv'
Offender_by_Age2018_path = 'Resources/Offender Age_2018.csv'
Offender_by_Age2019_path = 'Resources/Offender Age_2019.csv'
Offender_by_Age2020_path = 'Resources/Offender Age_2020.csv'
Offender_by_Age2021_path = 'Resources/Offender Age_2021.csv'
Offender_by_Age2022_path = 'Resources/Offender Age_2022.csv'

# %%
# this is the dataframes with all NaN values in tact. Keep these and don't amend them. 
# Use the  dataframe
offender10_base = pd.read_csv(Offender_by_Age2010_path, delimiter=',')
offender11_base = pd.read_csv(Offender_by_Age2011_path, delimiter=',')
offender12_base = pd.read_csv(Offender_by_Age2012_path, delimiter=',')
offender13_base = pd.read_csv(Offender_by_Age2013_path, delimiter=',')
offender14_base = pd.read_csv(Offender_by_Age2014_path, delimiter=',')
offender15_base = pd.read_csv(Offender_by_Age2015_path, delimiter=',')
offender16_base = pd.read_csv(Offender_by_Age2016_path, delimiter=',')
offender17_base = pd.read_csv(Offender_by_Age2017_path, delimiter=',')
offender18_base = pd.read_csv(Offender_by_Age2018_path, delimiter=',')
offender19_base = pd.read_csv(Offender_by_Age2019_path, delimiter=',')
offender20_base = pd.read_csv(Offender_by_Age2020_path, delimiter=',')
offender21_base = pd.read_csv(Offender_by_Age2021_path, delimiter=',')
offender22_base = pd.read_csv(Offender_by_Age2022_path, delimiter=',')

# %%
offendersex = pd.read_csv(Offender_by_Sex_path, delimiter=',')
offendersex
# Out:
#     Year   Male  Female  Unknown
# 0   2022   2001     349      273
# 1   2021  15713    2503     3113
# 2   2020   2001     349      273
# 3   2019   1697     335      188
# 4   2018   1989     409      228
# 5   2017   2112     360      298
# 6   2016   2608     304      235
# 7   2015   2062     308      186
# 8   2014   2078     320      238
# 9   2013   2416     342      193
# 10  2012   2566     357      179
# 11  2011   2691     399      202
# 12  2010   2506     389      156

# %%
#Crimes by Gender in Illinois
data = {
    'years': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'male': [2506, 2691, 2566, 2416, 2078, 2062, 2608, 2112, 1989, 1697, 2001, 15713, 2001],
    'female': [389, 399, 357, 342, 320, 308, 304, 360, 409, 335, 349, 2503, 349],
}

offendersex = pd.DataFrame(data)

bar_width = 0.35
bar_positions_male = np.arange(len(offendersex))
bar_positions_female = bar_positions_male + bar_width

plt.bar(bar_positions_male, offendersex['male'], width=bar_width, label='Male Crimes', color='blue')
plt.bar(bar_positions_female, offendersex['female'], width=bar_width, label='Female Crimes', color='pink')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.title('Crimes by Gender in Illinois')
plt.xticks(bar_positions_male + bar_width / 2, offendersex['years'])
plt.legend()
plt.show()

plt.savefig('output_data/Crime_and_Gender.png')

# %%
#Age Groups and Crimes they Committed
data = {
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    '0-9': [50, 60, 45, 55, 65, 70, 75, 80, 85, 90, 95, 100, 110],
    '10-19': [70, 80, 75, 85, 95, 100, 110, 120, 130, 140, 150, 160, 170],
    '20-29': [967, 867,	684, 507, 519, 660,	604, 525, 426, 392, 423, 3945, 970],
    '30-39': [363, 382,	386, 333, 320, 347,	403, 395, 474, 370,	443, 3530, 5198],
    '40-49': [183, 164, 207, 178, 153, 156,	179, 146, 214, 143,	173, 1603,	2446],
    '50-59': [69, 96, 85, 72, 90, 80, 99, 93, 114, 93, 136, 895, 1452],
    '60-69': [9, 18, 20, 13, 9, 17,	24,	18,	19,	22,	33,	290, 494],
    '70-79': [1, 2,	6,	4,	1,	4,	1,	5,	6,	5,	4,	54,	88],
    '80-89': [0, 1,	2,	2,	0,	1,	0,	2,	0,	1,	2,	14,	34],
    '90 and older': [17, 2,	0,	5,	2,	0,	0,	0,	0,	0,	0,	50,	65], 
}

age_df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))

for age_group in age_df.columns[1:]:
    plt.plot(age_df['Year'], age_df[age_group], label=age_group)

plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.title('Crime by Age Group and Year')
plt.legend()
plt.show()

# %%
financial_df = pd.read_csv(financial_file)
financial_df.head()
# Out:
#           City          Fire        Police  Total Emergency Services  \
# 0      Chicago  5.140089e+08  1.271732e+09              1.785741e+09
# 1  Springfield  2.284566e+07  4.163217e+07              6.447783e+07
# 2   Park Ridge  5.977756e+06  7.878832e+06              1.385659e+07
# 3   Naperville  2.460522e+07  2.414588e+07              4.875111e+07
# 4  Bolingbrook  2.814417e+07  2.120895e+07              4.935312e+07
#
#    Population
# 0     8936783
# 1      111711
# 2       37419
# 3      148754
# 4       73131

# %%
#Total amount paid to the emergency services departments per city
cities = financial_df["City"]
fire_per_city = []
police_per_city = []

for city in cities:
    fire_salaries = (financial_df.loc[financial_df["City"] == city, "Fire"].sum())/1000000
    police_salaries = (financial_df.loc[financial_df["City"] == city, "Police"].sum())/1000000
    fire_per_city.append(fire_salaries)
    police_per_city.append(police_salaries)

x_axis = np.arange(len(cities))
plt.figure(figsize=(8, 6))

plt.bar(x_axis - 0.2, fire_per_city, width=0.4, label='Fire Salaries', color='blue')
plt.bar(x_axis + 0.2, police_per_city, width=0.4, label='Police Salaries', color='green')

plt.title("Total Amounts Paid for Emergency Services per City")
plt.xlabel("City")
plt.ylabel("Amount Paid for Services (in millions)")
plt.xticks(x_axis, cities)
plt.legend() 

plt.tight_layout()
plt.show()
plt.savefig("output_data/EMS_per_City.png")

# %%
#What is the average amount per person of emergency services in each city?
cities = financial_df["City"]
average_ems_per_person = []

for city in cities:
    total_ems_expenditure = financial_df.loc[financial_df["City"] == city, "Total Emergency Services"].sum()
    total_population = financial_df.loc[financial_df["City"] == city, "Population"].sum()

    if total_population != 0:
        ems_per_person = total_ems_expenditure / total_population
        average_ems_per_person.append(ems_per_person)
    else:
        average_ems_per_person.append(0)

for city, average_ems in zip(cities, average_ems_per_person):
    print(f"{city}: {average_ems}")

plt.figure(figsize=(10, 6))

sns.swarmplot(x="City", y=average_ems_per_person, data=financial_df)

plt.xlabel("City")
plt.ylabel("EMS Expenditure per Person")
plt.title("EMS Expenditure per Person by City")
plt.xticks(rotation=45, ha="center")
plt.show()
plt.savefig("output_data/EMS_per_Person")
# Out:
# Chicago: 199.81925766799978
# Springfield: 577.1842080905193
# Park Ridge: 370.30888051524624
# Naperville: 327.72971483119784
# Bolingbrook: 674.8591498817192
