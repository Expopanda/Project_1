# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Store filepath in a variable and the data into a Pandas DataFrame
file = Path("../Project_1/Resources/FBI_(15-19)_national_new_shunjia.xls")
FBI_national_15to19_shunjia = pd.read_excel(file)

FBI_national_15to19_shunjia.to_csv ('FBI_national_15to19_shunjia.csv')

# show the dataframe 
FBI_national_15to19_shunjia
# Out:
#          Classification       2015       2016       2017       2018  \
# 0                Murder    15883.0    17413.0    17294.0    16374.0
# 1                  Rape   126134.0   132414.0   135666.0   143765.0
# 2               Robbery   328109.0   332797.0   320596.0   281278.0
# 3              Burglary  1587564.0  1516405.0  1397045.0  1235013.0
# 4        Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0
# 5   Motor vehicle theft   713063.0   767290.0   772943.0   751904.0
# 6                   NaN        NaN        NaN        NaN        NaN
# 7                   NaN        NaN        NaN        NaN        NaN
# 8                   NaN        NaN        NaN        NaN        NaN
# 9                   NaN        NaN        NaN        NaN        NaN
# 10                             NaN        NaN        NaN        NaN
#
#          2019  Unnamed: 6 Unnamed: 7
# 0     16425.0         NaN
# 1    139815.0         NaN        NaN
# 2    267988.0         NaN        NaN
# ...

# %%
#cleanup the data by rows 

rows_to_drop_df = FBI_national_15to19_shunjia.drop(labels=range(6,11), axis=0)

rows_to_drop_df
# Out:
#         Classification       2015       2016       2017       2018       2019  \
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN

# %%
#cleanup the data by columns 
columns_to_drop_df  = rows_to_drop_df.drop(columns=["Unnamed: 6", "Unnamed: 7"])

columns_to_drop_df
# Out:
#         Classification       2015       2016       2017       2018       2019
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0

# %%
clean_data= columns_to_drop_df
clean_data
# Out:
#         Classification       2015       2016       2017       2018       2019
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0

# %%
# charts ....

# %%
# Store filepath in a variable and the data into a Pandas DataFrame
file_2 = Path("../Project_1/Resources/FBI_national_change_new_shunjia.xls")
FBI_national_change_shunjia = pd.read_excel(file_2)

FBI_national_change_shunjia.to_csv ('FBI_national_change_shunjia.csv')

# show the dataframe 
FBI_national_change_shunjia
# Out:
#        Years  Unnamed: 1  Violent \ncrime1  Violent \ncrime \nrate   \
# 0  2019/2018         NaN              -0.5                     -1.0
# 1  2019/2015         NaN               0.4                     -1.9
# 2  2019/2010         NaN              -3.8                     -9.3
#
#    Murder and \nnonnegligent \nmanslaughter  \
# 0                                       0.3
# 1                                       3.4
# 2                                      11.6
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                              -0.2
# 1                                               1.1
# 2                                               5.1
#
#    Rape\n(revised \ndefinition)2  Rape\n(revised \ndefinition) \nrate2  \
# 0                           -2.7                                  -3.2
# 1                           10.8                                   8.4
# 2                            NaN                                   NaN
#
# ...

# %%
# cleanup data by rows
rows_to_drop_df = FBI_national_change_shunjia.drop([0])

rows_to_drop_df
# Out:
#        Years  Unnamed: 1  Violent \ncrime1  Violent \ncrime \nrate   \
# 1  2019/2015         NaN               0.4                     -1.9
# 2  2019/2010         NaN              -3.8                     -9.3
#
#    Murder and \nnonnegligent \nmanslaughter  \
# 1                                       3.4
# 2                                      11.6
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 1                                               1.1
# 2                                               5.1
#
#    Rape\n(revised \ndefinition)2  Rape\n(revised \ndefinition) \nrate2  \
# 1                           10.8                                   8.4
# 2                            NaN                                   NaN
#
#    Rape\n(legacy \ndefinition)3  Rape\n(legacy \ndefinition) \nrate3  ...  \
# 1                           7.6                                  5.2  ...
# 2                          14.7                                  8.1  ...
#
# ...
