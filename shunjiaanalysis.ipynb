# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import hvplot.pandas
import geopandas as gpd

# %%
# import the state files
file_1 = Path("../Project_1/Resources/FBI_2010_illinois_amended.csv")
file_2 = Path("../Project_1/Resources/FBI_2011_illinois_amended.csv")
file_3 = Path("../Project_1/Resources/FBI_2012_illinois_amended.csv")
file_4 = Path("../Project_1/Resources/FBI_2013_illinois_amended.csv")
file_5 = Path("../Project_1/Resources/FBI_2014_illinois_amended.csv")
file_6 = Path("../Project_1/Resources/FBI_2015_illinois_amended.csv")
file_7 = Path("../Project_1/Resources/FBI_2016_illinois_amended.csv")
file_8 = Path("../Project_1/Resources/FBI_2017_illinois_amended.csv")
file_9 = Path("../Project_1/Resources/FBI_2018_illinois_amended.csv")
file_10 = Path("../Project_1/Resources/FBI_2019_illinois_amended.csv")

# Read the CSV files into a DataFrame
data_file_1 = pd.read_csv(file_1)
data_file_2 = pd.read_csv(file_2)
data_file_3 = pd.read_csv(file_3)
data_file_4 = pd.read_csv(file_4)
data_file_5 = pd.read_csv(file_5)
data_file_6 = pd.read_csv(file_6)
data_file_7 = pd.read_csv(file_7)
data_file_8 = pd.read_csv(file_8)
data_file_9 = pd.read_csv(file_9)
data_file_10 = pd.read_csv(file_10)

# Remove noisy columns
columns =['City','Population','Violent crime',	'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',	'Aggravated Assault',
         'Property Crime',	'Burglary',	'Larceny-theft', 'Motor vehicle theft',	'Arson']
data_file_1 =data_file_1[columns]   
data_file_2 =data_file_2[columns] 
data_file_3 =data_file_3[columns] 
data_file_4 =data_file_4[columns]       
data_file_5 =data_file_5[columns] 
data_file_6 =data_file_6[columns] 
data_file_7 =data_file_7[columns] 
data_file_8 =data_file_8[columns] 
data_file_9 =data_file_9[columns] 
data_file_10 =data_file_10[columns] 

# Print the resulting DataFrame
data_file_10.head()
# Out:
#         City Population Violent crime  Murder and Non-Negligent Manslaughter  \
# 0    Addison     36,676            73                                      0
# 1      Aledo      3,448             0                                      0
# 2     Alexis        785             1                                      0
# 3  Algonquin     31,016            23                                      0
# 4     Alsip2     18,830            53                                      0
#
#   Rape Robbery Aggravated Assault Property Crime Burglary Larceny-theft  \
# 0   25      23                 25            423       52           344
# 1    0       0                  0             39        7            30
# 2    0       0                  1             12        1            10
# 3    6       3                 14            303       16           285
# 4    8      13                 32            NaN       61           378
#
#   Motor vehicle theft  Arson
# 0                  27    0.0
# 1                   2    0.0
# 2                   1    0.0
# 3                   2    1.0
# 4                 NaN    0.0

# %%
data_file_1
# Out:
#           City Population Violent crime  \
# 0      Addison     36,581            67
# 1       Albany        917             0
# 2        Aledo      3,466            11
# 3    Algonquin     30,848            79
# 4        Alton     28,841           174
# ..         ...        ...           ...
# 422  Yorkville     18,182            18
# 423        NaN        NaN           NaN
# 424        NaN        NaN           NaN
# 425        NaN        NaN           NaN
# 426        NaN        NaN           NaN
#
#      Murder and Non-Negligent Manslaughter  Rape Robbery Aggravated Assault  \
# 0                                      0.0  16.0      17                 34
# 1                                      0.0   0.0       0                  0
# 2                                      0.0   0.0       0                 11
# 3                                      0.0   2.0       2                 75
# 4                                      4.0  16.0      27                127
# ..                                     ...   ...     ...                ...
# 422                                    0.0   3.0       1                 14
# 423                                    NaN   NaN     NaN                NaN
# 424                                    NaN   NaN     NaN                NaN
# 425                                    NaN   NaN     NaN                NaN
# 426                                    NaN   NaN     NaN                NaN
#
#     Property Crime Burglary Larceny-theft Motor vehicle theft  Arson
# 0              827      109           662                  56   12.0
# 1               24       14             9                   1    0.0
# 2               91       23            63                   5    0.0
# 3              529       50           476                   3    2.0
# 4            1,265      292           913                  60   12.0
# ..             ...      ...           ...                 ...    ...
# 422            214       50           162                   2    3.0
# 423            NaN      NaN           NaN                 NaN    NaN
# 424            NaN      NaN           NaN                 NaN    NaN
# 425            NaN      NaN           NaN                 NaN    NaN
# 426            NaN      NaN           NaN                 NaN    NaN
#
# [427 rows x 12 columns]

# %%
#Identify specific citys in different files (years)
All_Cities={}
city_list = ["Naperville","Chicago", "Springfield","Park Ridge","Bolingbrook"]
for City in city_list:
      
  row_2010  =data_file_1[data_file_1['City']==City]
  row_2010['Year'] ='2010'
  row_2011  =data_file_2[data_file_2['City']==City]
  row_2011['Year'] ='2011'
  row_2012  =data_file_3[data_file_3['City']==City]
  row_2012['Year'] ='2012'
  row_2013  =data_file_4[data_file_4['City']==City]
  row_2013['Year'] ='2013'
  row_2014  =data_file_5[data_file_5['City']==City]
  row_2014['Year'] ='2014'
  row_2015  =data_file_6[data_file_6['City']==City]
  row_2015['Year'] ='2015'
  row_2016  =data_file_7[data_file_7['City']==City]
  row_2016['Year'] ='2016'    
  row_2017  =data_file_8[data_file_8['City']==City]
  row_2017['Year'] ='2017'
  row_2018  =data_file_9[data_file_9['City']==City]
  row_2018['Year'] ='2018'
  row_2019  =data_file_10[data_file_10['City']==City]
  row_2019['Year'] ='2019'

  rows = [row_2010, row_2011, row_2012,row_2013, row_2014,row_2015, row_2016, row_2017,row_2018, row_2019]

  result = pd.concat(rows)

  All_Cities[City] = result
# Out:
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2013['Year'] ='2013'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2014['Year'] ='2014'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2015['Year'] ='2015'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2016['Year'] ='2016'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2017['Year'] ='2017'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2018['Year'] ='2018'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2010['Year'] ='2010'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2013['Year'] ='2013'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2014['Year'] ='2014'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2015['Year'] ='2015'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2016['Year'] ='2016'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2017['Year'] ='2017'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2018['Year'] ='2018'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2019['Year'] ='2019'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2010['Year'] ='2010'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2013['Year'] ='2013'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2014['Year'] ='2014'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2015['Year'] ='2015'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2016['Year'] ='2016'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2017['Year'] ='2017'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2018['Year'] ='2018'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2019['Year'] ='2019'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2010['Year'] ='2010'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2013['Year'] ='2013'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2014['Year'] ='2014'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2016['Year'] ='2016'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2017['Year'] ='2017'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2018['Year'] ='2018'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2019['Year'] ='2019'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2013['Year'] ='2013'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2014['Year'] ='2014'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2015['Year'] ='2015'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2016['Year'] ='2016'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2017['Year'] ='2017'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2018['Year'] ='2018'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2210904803.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2019['Year'] ='2019'

# %%
# get the new 5 cities dataframes 
FBI_df_Naperville = All_Cities['Naperville']
FBI_df_Chicago = All_Cities['Chicago']
FBI_df_Springfield = All_Cities['Springfield']
FBI_df_Park_Ridge = All_Cities['Park Ridge']
FBI_df_Bolingbrook = All_Cities['Bolingbrook']

FBI_df_Naperville
# Out:
#            City Population Violent crime  \
# 216  Naperville    142,280           112
# 320  Naperville    142,840           119
# 315  Naperville    144,221           105
# 300  Naperville    145,510           113
# 325  Naperville    147,101           128
# 333  Naperville    148,070            92
# 335  Naperville    147,934           136
# 324  Naperville    148,457           102
#
#      Murder and Non-Negligent Manslaughter Rape Robbery Aggravated Assault  \
# 216                                    2.0  4.0      24                 82
# 320                                    3.0  7.0      24                 85
# 315                                    0.0  7.0      21                 77
# 300                                    1.0    8      20                 84
# 325                                    0.0   14      27                 87
# 333                                    0.0   15      34                 43
# 335                                    1.0   22      33                 80
# 324                                    0.0   29      21                 52
#
#     Property Crime Burglary Larceny-theft Motor vehicle theft  Arson  Year
# 216          2,110      300         1,768                  42    8.0  2011
# 320          2,044      255         1,748                  41   16.0  2012
# 315          1,869      225         1,610                  34    2.0  2013
# 300          1,634      176         1,421                  37    3.0  2014
# 325          1,652      161         1,458                  33    3.0  2015
# 333          1,587      141         1,401                  45    4.0  2016
# 335          1,716      129         1,540                  47    8.0  2017
# 324            NaN      163           NaN                  39    0.0  2018

# %%
#convert 5 cities dataframes to csv files 
FBI_df_Naperville.to_csv('FBI_df_Naperville.csv', index=False)
FBI_df_Chicago.to_csv('FBI_df_Chicago.csv', index=False)
FBI_df_Springfield.to_csv('FBI_df_Springfield.csv', index=False)
FBI_df_Park_Ridge.to_csv('FBI_df_Park_Ridge.csv', index=False)
FBI_df_Bolingbrook.to_csv('FBI_df_Bolingbrook.csv', index=False)

# Specify the path to save the CSV file
file_path = ("../Project_1/Resources/FBI_df_Naperville.csv,FBI_df_Chicago.csv,FBI_df_Springfield.csv,FBI_df_Park_Ridge.csv,FBI_df_Bolingbrook.csv")

FBI_df_Naperville
# Out:
#            City Population Violent crime  \
# 216  Naperville    142,280           112
# 320  Naperville    142,840           119
# 315  Naperville    144,221           105
# 300  Naperville    145,510           113
# 325  Naperville    147,101           128
# 333  Naperville    148,070            92
# 335  Naperville    147,934           136
# 324  Naperville    148,457           102
#
#      Murder and Non-Negligent Manslaughter Rape Robbery Aggravated Assault  \
# 216                                    2.0  4.0      24                 82
# 320                                    3.0  7.0      24                 85
# 315                                    0.0  7.0      21                 77
# 300                                    1.0    8      20                 84
# 325                                    0.0   14      27                 87
# 333                                    0.0   15      34                 43
# 335                                    1.0   22      33                 80
# 324                                    0.0   29      21                 52
#
#     Property Crime Burglary Larceny-theft Motor vehicle theft  Arson  Year
# 216          2,110      300         1,768                  42    8.0  2011
# 320          2,044      255         1,748                  41   16.0  2012
# 315          1,869      225         1,610                  34    2.0  2013
# 300          1,634      176         1,421                  37    3.0  2014
# 325          1,652      161         1,458                  33    3.0  2015
# 333          1,587      141         1,401                  45    4.0  2016
# 335          1,716      129         1,540                  47    8.0  2017
# 324            NaN      163           NaN                  39    0.0  2018

# %%
# combine the 5 cities dataframes into one df by "years"
# Create a list of DataFrames
df = [FBI_df_Naperville, FBI_df_Chicago, FBI_df_Springfield, FBI_df_Park_Ridge, FBI_df_Bolingbrook]

# Concatenate DataFrames based on the "years" column
combined_df = pd.concat(df, ignore_index=True)

# Now, 'combined_df' contains the data from all the DataFrames with a common "years" column.
combined_df.head()
# Out:
#          City Population Violent crime  Murder and Non-Negligent Manslaughter  \
# 0  Naperville    142,280           112                                    2.0
# 1  Naperville    142,840           119                                    3.0
# 2  Naperville    144,221           105                                    0.0
# 3  Naperville    145,510           113                                    1.0
# 4  Naperville    147,101           128                                    0.0
#
#   Rape Robbery Aggravated Assault Property Crime Burglary Larceny-theft  \
# 0  4.0      24                 82          2,110      300         1,768
# 1  7.0      24                 85          2,044      255         1,748
# 2  7.0      21                 77          1,869      225         1,610
# 3    8      20                 84          1,634      176         1,421
# 4   14      27                 87          1,652      161         1,458
#
#   Motor vehicle theft  Arson  Year
# 0                  42    8.0  2011
# 1                  41   16.0  2012
# 2                  34    2.0  2013
# 3                  37    3.0  2014
# 4                  33    3.0  2015

# %%
#filter cities data based on crime classfication and the years
# select columns by name

combined_filter_df = combined_df.filter(items=['City','Year', 'Population','Rape','Robbery','Burglary','Larceny-theft','Motor vehicle theft'])

combined_filter_df.info
# Out:
# <bound method DataFrame.info of            City  Year Population   Rape Robbery Burglary Larceny-theft  \
# 0    Naperville  2011    142,280    4.0      24      300         1,768
# 1    Naperville  2012    142,840    7.0      24      255         1,748
# 2    Naperville  2013    144,221    7.0      21      225         1,610
# 3    Naperville  2014    145,510      8      20      176         1,421
# 4    Naperville  2015    147,101     14      27      161         1,458
# 5    Naperville  2016    148,070     15      34      141         1,401
# 6    Naperville  2017    147,934     22      33      129         1,540
# 7    Naperville  2018    148,457     29      21      163           NaN
# 8       Chicago  2010  2,833,649    0.0  14,213   26,203        74,764
# 9       Chicago  2011  2,703,713    0.0  13,975   26,420        72,373
# 10      Chicago  2012  2,708,382    0.0  13,476   22,748        72,717
# 11      Chicago  2013  2,720,554    0.0  11,815   17,775        65,497
# 12      Chicago  2014  2,724,121  1,343   9,804   14,537        60,601
# 13      Chicago  2015  2,728,695  1,432   9,649   13,151        57,022
# 14      Chicago  2016  2,725,153  1,589  11,957   14,258        61,229
# 15      Chicago  2017  2,706,171  1,762  11,887   12,912        63,834
# 16      Chicago  2018  2,719,151  1,798   9,684   11,686        64,695
# 17      Chicago  2019  2,707,064  1,761   7,983    9,578        62,083
# 18  Springfield  2010    117,383  104.0     338    2,167         5,160
# 19  Springfield  2011    116,600  103.0     258    1,883         5,076
# 20  Springfield  2012    117,131   76.0     260    1,670         5,033
# 21  Springfield  2013    117,351   71.0     287    1,300         4,439
# 22  Springfield  2014    117,134     97     258    1,110         4,300
# 23  Springfield  2015    116,875    103     257    1,131         3,997
# 24  Springfield  2016    116,563     99     249    1,250         3,681
# 25  Springfield  2017    115,568     93     251    1,210         3,973
# 26  Springfield  2018    114,623     93     216    1,195         4,044
# 27  Springfield  2019    114,393    108     208    1,039         3,776
# 28   Park Ridge  2010     36,324    1.0       4      134           424
# 29   Park Ridge  2011     37,593    2.0       7      138           336
# 30   Park Ridge  2012     37,660    0.0      12      118           328
# 31   Park Ridge  2013     37,788    1.0       6       99           360
# 32   Park Ridge  2014     37,919      1       4       79           365
# 33   Park Ridge  2016     37,805      1       8       67           294
# 34   Park Ridge  2017     37,492      1       9       57           212
# 35   Park Ridge  2018     37,490      2       4       51           273
# 36   Park Ridge  2019     37,206      2       4       36           245
# 37  Bolingbrook  2011     73,587   25.0      49      261           915
# 38  Bolingbrook  2012     73,836   16.0      50      162           940
# 39  Bolingbrook  2013     74,224   17.0      38      118           952
# 40  Bolingbrook  2014     74,049     17      46       95           854
# 41  Bolingbrook  2015     74,356     24      22       79           866
# 42  Bolingbrook  2016     74,471     23      18      111           782
# 43  Bolingbrook  2017     74,692     34      27       69           596
# 44  Bolingbrook  2018     75,451     23      17       60           477
# 45  Bolingbrook  2019     75,394     28      19       65           501
#
#    Motor vehicle theft
# 0                   42
# 1                   41
# 2                   34
# 3                   37
# 4                   33
# 5                   45
# 6                   47
# 7                   39
# 8               19,078
# 9               19,446
# 10              17,001
# 11              12,636
# 12              10,023
# 13              10,222
# 14              11,473
# 15              11,578
# 16              10,132
# 17               9,081
# 18                 240
# 19                 217
# 20                 242
# 21                 166
# 22                 125
# 23                 193
# 24                 227
# 25                 313
# 26                 248
# 27                 265
# 28                  13
# 29                   6
# 30                  13
# 31                  10
# 32                   7
# 33                  14
# 34                   9
# 35                  17
# 36                  14
# 37                  45
# 38                  37
# 39                  61
# 40                  37
# 41                  46
# 42                  51
# 43                  70
# 44                  55
# 45                  84  >

# %%
# Step 1: Create a set of years for each city
years_by_city = {}
cities = combined_filter_df['City'].unique()

for city in cities:
    years_by_city[city] = set(combined_filter_df[combined_filter_df['City'] == city]['Year'])

# Step 2: Find the intersection of these sets to identify the common years
overlap_years = set.intersection(*years_by_city.values())

# 'overlap_years' now contains the common years among all cities.
print("Overlap Years:", sorted(list(overlap_years)))
# Out:
# Overlap Years: ['2011', '2012', '2013', '2014', '2016', '2017', '2018']

# %%
#creat the new df based on the overlap_years
FBI_new_city_df = combined_filter_df[combined_filter_df['Year'].isin(overlap_years)]
FBI_new_city_df.info
# Out:
# <bound method DataFrame.info of            City  Year Population   Rape Robbery Burglary Larceny-theft  \
# 0    Naperville  2011    142,280    4.0      24      300         1,768
# 1    Naperville  2012    142,840    7.0      24      255         1,748
# 2    Naperville  2013    144,221    7.0      21      225         1,610
# 3    Naperville  2014    145,510      8      20      176         1,421
# 5    Naperville  2016    148,070     15      34      141         1,401
# 6    Naperville  2017    147,934     22      33      129         1,540
# 7    Naperville  2018    148,457     29      21      163           NaN
# 9       Chicago  2011  2,703,713    0.0  13,975   26,420        72,373
# 10      Chicago  2012  2,708,382    0.0  13,476   22,748        72,717
# 11      Chicago  2013  2,720,554    0.0  11,815   17,775        65,497
# 12      Chicago  2014  2,724,121  1,343   9,804   14,537        60,601
# 14      Chicago  2016  2,725,153  1,589  11,957   14,258        61,229
# 15      Chicago  2017  2,706,171  1,762  11,887   12,912        63,834
# 16      Chicago  2018  2,719,151  1,798   9,684   11,686        64,695
# 19  Springfield  2011    116,600  103.0     258    1,883         5,076
# 20  Springfield  2012    117,131   76.0     260    1,670         5,033
# 21  Springfield  2013    117,351   71.0     287    1,300         4,439
# 22  Springfield  2014    117,134     97     258    1,110         4,300
# 24  Springfield  2016    116,563     99     249    1,250         3,681
# 25  Springfield  2017    115,568     93     251    1,210         3,973
# 26  Springfield  2018    114,623     93     216    1,195         4,044
# 29   Park Ridge  2011     37,593    2.0       7      138           336
# 30   Park Ridge  2012     37,660    0.0      12      118           328
# 31   Park Ridge  2013     37,788    1.0       6       99           360
# 32   Park Ridge  2014     37,919      1       4       79           365
# 33   Park Ridge  2016     37,805      1       8       67           294
# 34   Park Ridge  2017     37,492      1       9       57           212
# 35   Park Ridge  2018     37,490      2       4       51           273
# 37  Bolingbrook  2011     73,587   25.0      49      261           915
# 38  Bolingbrook  2012     73,836   16.0      50      162           940
# 39  Bolingbrook  2013     74,224   17.0      38      118           952
# 40  Bolingbrook  2014     74,049     17      46       95           854
# 42  Bolingbrook  2016     74,471     23      18      111           782
# 43  Bolingbrook  2017     74,692     34      27       69           596
# 44  Bolingbrook  2018     75,451     23      17       60           477
#
#    Motor vehicle theft
# 0                   42
# 1                   41
# 2                   34
# 3                   37
# 5                   45
# 6                   47
# 7                   39
# 9               19,446
# 10              17,001
# 11              12,636
# 12              10,023
# 14              11,473
# 15              11,578
# 16              10,132
# 19                 217
# 20                 242
# 21                 166
# 22                 125
# 24                 227
# 25                 313
# 26                 248
# 29                   6
# 30                  13
# 31                  10
# 32                   7
# 33                  14
# 34                   9
# 35                  17
# 37                  45
# 38                  37
# 39                  61
# 40                  37
# 42                  51
# 43                  70
# 44                  55  >

# %%
FBI_new_city_df.dtypes
# Out:
# City                   object
# Year                   object
# Population             object
# Rape                   object
# Robbery                object
# Burglary               object
# Larceny-theft          object
# Motor vehicle theft    object
# dtype: object

# %%
FBI_new_city_df["Population"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Population"]]
FBI_new_city_df["Rape"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Rape"]]
FBI_new_city_df["Robbery"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Robbery"]]
FBI_new_city_df["Burglary"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Burglary"]]
FBI_new_city_df["Larceny-theft"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Larceny-theft"]]
FBI_new_city_df["Motor vehicle theft"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Motor vehicle theft"]]
# Out:
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Population"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Population"]]
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Rape"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Rape"]]
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Robbery"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Robbery"]]
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Burglary"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Burglary"]]
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Larceny-theft"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Larceny-theft"]]
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_23293/2344066284.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBI_new_city_df["Motor vehicle theft"] = [float(str(i).replace(",", "")) for i in FBI_new_city_df["Motor vehicle theft"]]

# %%
FBI_new_city_df
# Out:
#            City  Year  Population    Rape  Robbery  Burglary  Larceny-theft  \
# 0    Naperville  2011    142280.0     4.0     24.0     300.0         1768.0
# 1    Naperville  2012    142840.0     7.0     24.0     255.0         1748.0
# 2    Naperville  2013    144221.0     7.0     21.0     225.0         1610.0
# 3    Naperville  2014    145510.0     8.0     20.0     176.0         1421.0
# 5    Naperville  2016    148070.0    15.0     34.0     141.0         1401.0
# 6    Naperville  2017    147934.0    22.0     33.0     129.0         1540.0
# 7    Naperville  2018    148457.0    29.0     21.0     163.0            NaN
# 9       Chicago  2011   2703713.0     0.0  13975.0   26420.0        72373.0
# 10      Chicago  2012   2708382.0     0.0  13476.0   22748.0        72717.0
# 11      Chicago  2013   2720554.0     0.0  11815.0   17775.0        65497.0
# 12      Chicago  2014   2724121.0  1343.0   9804.0   14537.0        60601.0
# 14      Chicago  2016   2725153.0  1589.0  11957.0   14258.0        61229.0
# 15      Chicago  2017   2706171.0  1762.0  11887.0   12912.0        63834.0
# 16      Chicago  2018   2719151.0  1798.0   9684.0   11686.0        64695.0
# 19  Springfield  2011    116600.0   103.0    258.0    1883.0         5076.0
# 20  Springfield  2012    117131.0    76.0    260.0    1670.0         5033.0
# 21  Springfield  2013    117351.0    71.0    287.0    1300.0         4439.0
# 22  Springfield  2014    117134.0    97.0    258.0    1110.0         4300.0
# 24  Springfield  2016    116563.0    99.0    249.0    1250.0         3681.0
# 25  Springfield  2017    115568.0    93.0    251.0    1210.0         3973.0
# 26  Springfield  2018    114623.0    93.0    216.0    1195.0         4044.0
# 29   Park Ridge  2011     37593.0     2.0      7.0     138.0          336.0
# 30   Park Ridge  2012     37660.0     0.0     12.0     118.0          328.0
# 31   Park Ridge  2013     37788.0     1.0      6.0      99.0          360.0
# 32   Park Ridge  2014     37919.0     1.0      4.0      79.0          365.0
# 33   Park Ridge  2016     37805.0     1.0      8.0      67.0          294.0
# 34   Park Ridge  2017     37492.0     1.0      9.0      57.0          212.0
# 35   Park Ridge  2018     37490.0     2.0      4.0      51.0          273.0
# 37  Bolingbrook  2011     73587.0    25.0     49.0     261.0          915.0
# 38  Bolingbrook  2012     73836.0    16.0     50.0     162.0          940.0
# 39  Bolingbrook  2013     74224.0    17.0     38.0     118.0          952.0
# 40  Bolingbrook  2014     74049.0    17.0     46.0      95.0          854.0
# 42  Bolingbrook  2016     74471.0    23.0     18.0     111.0          782.0
# 43  Bolingbrook  2017     74692.0    34.0     27.0      69.0          596.0
# 44  Bolingbrook  2018     75451.0    23.0     17.0      60.0          477.0
#
#     Motor vehicle theft
# 0                  42.0
# 1                  41.0
# 2                  34.0
# 3                  37.0
# 5                  45.0
# 6                  47.0
# 7                  39.0
# 9               19446.0
# 10              17001.0
# 11              12636.0
# 12              10023.0
# 14              11473.0
# 15              11578.0
# 16              10132.0
# 19                217.0
# 20                242.0
# 21                166.0
# 22                125.0
# 24                227.0
# 25                313.0
# 26                248.0
# 29                  6.0
# 30                 13.0
# 31                 10.0
# 32                  7.0
# 33                 14.0
# 34                  9.0
# 35                 17.0
# 37                 45.0
# 38                 37.0
# 39                 61.0
# 40                 37.0
# 42                 51.0
# 43                 70.0
# 44                 55.0

# %%
#create new df based on the city use groupby
new_city_df = FBI_new_city_df.groupby("City").sum().reset_index() 

new_city_df
# Out:
#           City                          Year  Population    Rape  Robbery  \
# 0  Bolingbrook  2011201220132014201620172018    520310.0   155.0    245.0
# 1      Chicago  2011201220132014201620172018  19007245.0  6492.0  82598.0
# 2   Naperville  2011201220132014201620172018   1019312.0    92.0    177.0
# 3   Park Ridge  2011201220132014201620172018    263747.0     8.0     50.0
# 4  Springfield  2011201220132014201620172018    814970.0   632.0   1779.0
#
#    Burglary  Larceny-theft  Motor vehicle theft
# 0     876.0         5516.0                356.0
# 1  120336.0       460946.0              92289.0
# 2    1389.0         9488.0                285.0
# 3     609.0         2168.0                 76.0
# 4    9618.0        30546.0               1538.0

# %%
# drop the year coulummn
city_df = new_city_df.drop('Year', axis=1)
city_df
# Out:
#           City  Population    Rape  Robbery  Burglary  Larceny-theft  \
# 0  Bolingbrook    520310.0   155.0    245.0     876.0         5516.0
# 1      Chicago  19007245.0  6492.0  82598.0  120336.0       460946.0
# 2   Naperville   1019312.0    92.0    177.0    1389.0         9488.0
# 3   Park Ridge    263747.0     8.0     50.0     609.0         2168.0
# 4  Springfield    814970.0   632.0   1779.0    9618.0        30546.0
#
#    Motor vehicle theft
# 0                356.0
# 1              92289.0
# 2                285.0
# 3                 76.0
# 4               1538.0

# %%
list# la 
lat = [41.698886802861495,41.88133514587103,41.750138401651164,42.01135761330413,39.78400207341597]
lon = [-88.07053643374739,-87.64413102584447, -88.15330347221709,-87.84112658301977,-89.65994649111914]

# %%
city_df["latitude"] = lat
city_df["longitude"] = lon
city_df
# Out:
#           City  Population    Rape  Robbery  Burglary  Larceny-theft  \
# 0  Bolingbrook    520310.0   155.0    245.0     876.0         5516.0
# 1      Chicago  19007245.0  6492.0  82598.0  120336.0       460946.0
# 2   Naperville   1019312.0    92.0    177.0    1389.0         9488.0
# 3   Park Ridge    263747.0     8.0     50.0     609.0         2168.0
# 4  Springfield    814970.0   632.0   1779.0    9618.0        30546.0
#
#    Motor vehicle theft   latitude  longitude
# 0                356.0  41.698887 -88.070536
# 1              92289.0  41.881335 -87.644131
# 2                285.0  41.750138 -88.153303
# 3                 76.0  42.011358 -87.841127
# 4               1538.0  39.784002 -89.659946

# %%
#city_df['Severity_Rape']=[3,5,2,1,4]
#city_df['Severity_Robbery']=[3,5,2,1,4]
#city_df['Severity_Burglary']=[2,5,3,1,4]
#city_df['Severity_Larceny-theft']=[2,5,3,1,4]
#city_df['Severity_Motor vehicle theft']=[3,5,2,1,4]

city_df['Density_Rape']=city_df['Rape']/city_df['Population']
city_df['Density_Robbery']=city_df['Robbery']/city_df['Population']
city_df['Density_Burglary']=city_df['Burglary']/city_df['Population']
city_df['Density_Larceny-theft']=city_df['Larceny-theft']/city_df['Population']
city_df['Density_Motor vehicle theft']=city_df['Motor vehicle theft']/city_df['Population']

# %%
# Configure the map plot_3
map_plot = city_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Density_Rape",
    scale=500,
    color="City"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Density_Rape)

# %%
# Configure the map plot_3
map_plot = city_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Density_Robbery",
    scale=500,
    color="City"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Density_Robbery)

# %%
# Configure the map plot_3
map_plot = city_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Density_Burglary",
    scale=500,
    color="City"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Density_Burglary)

# %%
# Configure the map plot_3
map_plot = city_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Density_Larceny-theft",
    scale=500,
    color="City"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Density_Larceny-theft)

# %%
# Configure the map plot_3
map_plot = city_df.hvplot.points(
    "longitude",
    "latitude",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Density_Motor vehicle theft",
    scale=500,
    color="City"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Density_Motor vehicle theft)
