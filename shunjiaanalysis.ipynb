# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Store filepath in a variable and the data into a Pandas DataFrame
file = Path("../Project_1/Resources/FBI_national_new.xls")
FBI_national= pd.read_excel(file)

FBI_national.to_csv ('FBI_natioanl.csv')

# show the dataframe 
FBI_national
# Out:
#          Classification       2015       2016       2017       2018  \
# 0                Murder    15883.0    17413.0    17294.0    16374.0
# 1                  Rape   126134.0   132414.0   135666.0   143765.0
# 2               Robbery   328109.0   332797.0   320596.0   281278.0
# 3              Burglary  1587564.0  1516405.0  1397045.0  1235013.0
# 4        Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0
# 5   Motor vehicle theft   713063.0   767290.0   772943.0   751904.0
# 6                   NaN        NaN        NaN        NaN        NaN
# 7                   NaN        NaN        NaN        NaN        NaN
# 8                   NaN        NaN        NaN        NaN        NaN
# 9                   NaN        NaN        NaN        NaN        NaN
# 10                             NaN        NaN        NaN        NaN
#
#          2019  Unnamed: 6 Unnamed: 7
# 0     16425.0         NaN
# 1    139815.0         NaN        NaN
# 2    267988.0         NaN        NaN
# ...

# %%
#cleanup the data by rows 

rows_to_drop_df = FBI_national.drop(labels=range(6,11), axis=0)

rows_to_drop_df
# Out:
#         Classification       2015       2016       2017       2018       2019  \
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN

# %%
#cleanup the data by columns 
columns_to_drop_df = rows_to_drop_df.drop(columns=["Unnamed: 6", "Unnamed: 7"])

columns_to_drop_df
# Out:
#         Classification       2015       2016       2017       2018       2019
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0

# %%
clean_data_national = columns_to_drop_df
clean_data_national
# Out:
#         Classification       2015       2016       2017       2018       2019
# 0               Murder    15883.0    17413.0    17294.0    16374.0    16425.0
# 1                 Rape   126134.0   132414.0   135666.0   143765.0   139815.0
# 2              Robbery   328109.0   332797.0   320596.0   281278.0   267988.0
# 3             Burglary  1587564.0  1516405.0  1397045.0  1235013.0  1117696.0
# 4       Larceny-theft   5723488.0  5644835.0  5513000.0  5232167.0  5086096.0
# 5  Motor vehicle theft   713063.0   767290.0   772943.0   751904.0   721885.0

# %%
# Store filepath in a variable and the data into a Pandas DataFrame
file_2 = Path("../Project_1/Resources/FBI_national_change_new.xls")
FBI_national_change = pd.read_excel(file_2)

FBI_national_change.to_csv ('FBI_national_change.csv')

# show the dataframe 
FBI_national_change
# Out:
#        Years  Unnamed: 1  Violent \ncrime1  Violent \ncrime \nrate   \
# 0  2019/2018         NaN              -0.5                     -1.0
# 1  2019/2015         NaN               0.4                     -1.9
# 2  2019/2010         NaN              -3.8                     -9.3
#
#    Murder and \nnonnegligent \nmanslaughter  \
# 0                                       0.3
# 1                                       3.4
# 2                                      11.6
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                              -0.2
# 1                                               1.1
# 2                                               5.1
#
#    Rape\n(revised \ndefinition)2  Rape\n(revised \ndefinition) \nrate2  \
# 0                           -2.7                                  -3.2
# 1                           10.8                                   8.4
# 2                            NaN                                   NaN
#
# ...

# %%
# cleanup data by rows
rows_to_drop_df = FBI_national_change.drop([0])

rows_to_drop_df
# Out:
#        Years  Unnamed: 1  Violent \ncrime1  Violent \ncrime \nrate   \
# 1  2019/2015         NaN               0.4                     -1.9
# 2  2019/2010         NaN              -3.8                     -9.3
#
#    Murder and \nnonnegligent \nmanslaughter  \
# 1                                       3.4
# 2                                      11.6
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 1                                               1.1
# 2                                               5.1
#
#    Rape\n(revised \ndefinition)2  Rape\n(revised \ndefinition) \nrate2  \
# 1                           10.8                                   8.4
# 2                            NaN                                   NaN
#
#    Rape\n(legacy \ndefinition)3  Rape\n(legacy \ndefinition) \nrate3  ...  \
# 1                           7.6                                  5.2  ...
# 2                          14.7                                  8.1  ...
#
# ...

# %%
# import the state files
file_1 = Path("../Project_1/Resources/FBI_2010_illinois_amended.csv")
file_2 = Path("../Project_1/Resources/FBI_2011_illinois_amended.csv")
file_3 = Path("../Project_1/Resources/FBI_2012_illinois_amended.csv")
file_4 = Path("../Project_1/Resources/FBI_2013_illinois_amended.csv")
file_5 = Path("../Project_1/Resources/FBI_2014_illinois_amended.csv")
file_6 = Path("../Project_1/Resources/FBI_2015_illinois_amended.csv")
file_7 = Path("../Project_1/Resources/FBI_2016_illinois_amended.csv")
file_8 = Path("../Project_1/Resources/FBI_2017_illinois_amended.csv")
file_9 = Path("../Project_1/Resources/FBI_2018_illinois_amended.csv")
file_10 = Path("../Project_1/Resources/FBI_2019_illinois_amended.csv")

# Read the CSV files into a DataFrame
data_file_1 = pd.read_csv(file_1)
data_file_2 = pd.read_csv(file_2)
data_file_3 = pd.read_csv(file_3)
data_file_4 = pd.read_csv(file_4)
data_file_5 = pd.read_csv(file_5)
data_file_6 = pd.read_csv(file_6)
data_file_7 = pd.read_csv(file_7)
data_file_8 = pd.read_csv(file_8)
data_file_9 = pd.read_csv(file_9)
data_file_10 = pd.read_csv(file_10)

# Remove noisy columns
columns =['City','Population','Violent crime',	'Murder and Non-Negligent Manslaughter', 'Rape', 'Robbery',	'Aggravated Assault',
         'Property Crime',	'Burglary',	'Larceny-theft', 'Motor vehicle theft',	'Arson']
data_file_1 =data_file_1[columns]   
data_file_2 =data_file_2[columns] 
data_file_3 =data_file_3[columns] 
data_file_4 =data_file_4[columns]       
data_file_5 =data_file_5[columns] 
data_file_6 =data_file_6[columns] 
data_file_7 =data_file_7[columns] 
data_file_8 =data_file_8[columns] 
data_file_9 =data_file_9[columns] 
data_file_10 =data_file_10[columns] 

# Print the resulting DataFrame
data_file_10.head()
# Out:
#         City Population Violent crime  Murder and Non-Negligent Manslaughter  \
# 0    Addison     36,676            73                                      0
# 1      Aledo      3,448             0                                      0
# 2     Alexis        785             1                                      0
# 3  Algonquin     31,016            23                                      0
# 4     Alsip2     18,830            53                                      0
#
#   Rape Robbery Aggravated Assault Property Crime Burglary Larceny-theft  \
# 0   25      23                 25            423       52           344
# 1    0       0                  0             39        7            30
# 2    0       0                  1             12        1            10
# 3    6       3                 14            303       16           285
# 4    8      13                 32            NaN       61           378
#
#   Motor vehicle theft  Arson
# 0                  27    0.0
# ...

# %%
#Identify specific citys in different files (years)

All_Cities={}

city_list = ["Naperville","Chicago", "Springfield","Park Ridge","Bolingbrook"]
for City in city_list:
      
  row_2010  =data_file_1[data_file_1['City']==City]
  row_2010['Year'] ='2010'
  row_2011  =data_file_2[data_file_2['City']==City]
  row_2011['Year'] ='2011'
  row_2012  =data_file_3[data_file_3['City']==City]
  row_2012['Year'] ='2012'
  row_2013  =data_file_4[data_file_4['City']==City]
  row_2013['Year'] ='2013'
  row_2014  =data_file_5[data_file_5['City']==City]
  row_2014['Year'] ='2014'
  row_2015  =data_file_6[data_file_6['City']==City]
  row_2015['Year'] ='2015'
  row_2016  =data_file_7[data_file_7['City']==City]
  row_2016['Year'] ='2016'    
  row_2017  =data_file_8[data_file_8['City']==City]
  row_2017['Year'] ='2017'
  row_2018  =data_file_9[data_file_9['City']==City]
  row_2018['Year'] ='2018'
  row_2019  =data_file_10[data_file_10['City']==City]
  row_2019['Year'] ='2019'

  rows = [row_2010, row_2011, row_2012,row_2013, row_2014,row_2015, row_2016, row_2017,row_2018, row_2019]

  result = pd.concat(rows)

  All_Cities[City] = result
# Out:
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_87146/2944968137.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2011['Year'] ='2011'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_87146/2944968137.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_2012['Year'] ='2012'
# /var/folders/rc/1q9yysq50wbgw9_t_whj8rcr0000gn/T/ipykernel_87146/2944968137.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
All_Cities
# Out:
# {'Naperville':            City Population Violent crime  \
#  216  Naperville    142,280           112
#  320  Naperville    142,840           119
#  315  Naperville    144,221           105
#  300  Naperville    145,510           113
#  325  Naperville    147,101           128
#  333  Naperville    148,070            92
#  335  Naperville    147,934           136
#  324  Naperville    148,457           102
#
#       Murder and Non-Negligent Manslaughter Rape Robbery Aggravated Assault  \
#  216                                    2.0  4.0      24                 82
#  320                                    3.0  7.0      24                 85
#  315                                    0.0  7.0      21                 77
#  300                                    1.0    8      20                 84
#  325                                    0.0   14      27                 87
#  333                                    0.0   15      34                 43
# ...

# %%
# get the new 5 cities dataframes 
FBI_df_Naperville =All_Cities['Naperville']
FBI_df_Chicago = All_Cities['Chicago']
FBI_df_Springfield = All_Cities['Springfield']
FBI_df_Park_Ridge = All_Cities['Park Ridge']
FBI_df_Bolingbrook = All_Cities['Bolingbrook']

# %%
#convert 5 cities dataframes to csv files 
FBI_df_Naperville.to_csv('FBI_df_Naperville.csv', index=False)
FBI_df_Chicago.to_csv('FBI_df_Chicago.csv', index=False)
FBI_df_Springfield.to_csv('FBI_df_Springfield.csv', index=False)
FBI_df_Park_Ridge.to_csv('FBI_df_Park_Ridge.csv', index=False)
FBI_df_Bolingbrook.to_csv('FBI_df_Bolingbrook.csv', index=False)

# Specify the path to save the CSV file
file_path = ("../Project_1/Resources/FBI_df_Naperville.csv,FBI_df_Chicago.csv,FBI_df_Springfield.csv,FBI_df_Park_Ridge.csv,FBI_df_Bolingbrook.csv")

# Save the DataFrame to the specified path
FBI_df_Naperville.to_csv('FBI_df_Naperville.csv', index=False)
FBI_df_Chicago.to_csv('FBI_df_Chicago.csv', index=False)
FBI_df_Springfield.to_csv('FBI_df_Springfield.csv', index=False)
FBI_df_Park_Ridge.to_csv('FBI_df_Park_Ridge.csv', index=False)
FBI_df_Bolingbrook.to_csv('FBI_df_Bolingbrook.csv', index=False)

FBI_df_Naperville
# Out:
#            City Population Violent crime  \
# 216  Naperville    142,280           112
# 320  Naperville    142,840           119
# 315  Naperville    144,221           105
# 300  Naperville    145,510           113
# 325  Naperville    147,101           128
# 333  Naperville    148,070            92
# 335  Naperville    147,934           136
# 324  Naperville    148,457           102
#
#      Murder and Non-Negligent Manslaughter Rape Robbery Aggravated Assault  \
# 216                                    2.0  4.0      24                 82
# 320                                    3.0  7.0      24                 85
# 315                                    0.0  7.0      21                 77
# 300                                    1.0    8      20                 84
# 325                                    0.0   14      27                 87
# 333                                    0.0   15      34                 43
# ...

# %%
# combine the 5 cities dataframes into one df by "years"
